# %%
import sys
import codecs
if sys.stdout.encoding != 'UTF-8':
    sys.stdout = codecs.getwriter('utf-8')(sys.stdout.buffer, 'strict')
if sys.stderr.encoding != 'UTF-8':
    sys.stderr = codecs.getwriter('utf-8')(sys.stderr.buffer, 'strict')
# Step 1: Import Required Modules (Enhanced)
import os
import traceback
from langchain.prompts import PromptTemplate
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import google.generativeai as genai
from pdfminer.high_level import extract_text
import re  # For text cleaning
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# Step 2: Configuration Settings
PDF_PATH = "Fundamentals_of_Electrical_Engineering_I_9648-pages-2.pdf"
EXTRACTED_TEXT_PATH = "extracted_text.txt"

# Configure Gemini API key
# Replace with your actual Gemini API key
GEMINI_API_KEY = ""
genai.configure(api_key=GEMINI_API_KEY)

# Step 3: Text Extraction & Cleaning
def extract_and_clean_pdf(pdf_path, output_path):
    """Extracts text from PDF and cleans it for processing"""
    try:
        # Extract raw text
        raw_text = extract_text(pdf_path)

        # Clean text: Remove excessive whitespace, headers/footers
        cleaned_text = re.sub(r'\s+', ' ', raw_text)  # Replace multiple spaces
        cleaned_text = re.sub(r'-\n', '', cleaned_text)  # Fix hyphenated words

        # Save cleaned text
        with open(output_path, "w", encoding="utf-8") as f:
            f.write(cleaned_text)

        return cleaned_text
    except Exception as e:
        raise RuntimeError(f"PDF extraction failed: {str(e)}")

# Step 4: Document Processing Pipeline
try:
    # Extract and clean PDF text
    print("Extracting and cleaning PDF text...")
    cleaned_text = extract_and_clean_pdf(PDF_PATH, EXTRACTED_TEXT_PATH)

    # Load cleaned text
    loader = TextLoader(EXTRACTED_TEXT_PATH, encoding="utf-8")
    documents = loader.load()

    # Split documents into chunks
    print("Splitting documents into chunks...")
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=256,
        chunk_overlap=200,
        length_function=len,
        add_start_index=True
    )
    texts = text_splitter.split_documents(documents)

    if not texts:
        raise ValueError("No valid text extracted after cleaning. Check PDF content.")

    # Create embeddings and vector store
    print("Creating vector database...")
    embeddings = HuggingFaceEmbeddings(
        model_name="sentence-transformers/all-mpnet-base-v2"
    )
    vectorstore = FAISS.from_documents(texts, embeddings)
    retriever = vectorstore.as_retriever(search_kwargs={"k": 4})  # Retrieve 4 relevant chunks

    # Step 5: LLM Initialization with Error Handling
    print("Initializing language model...")
    try:
        llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", google_api_key=GEMINI_API_KEY)
    except Exception as e:
        raise ConnectionError(f"LLM initialization failed. Check API token and model availability: {str(e)}")

    # Step 6: Enhanced Prompt Engineering
    outline_template = """As an expert in integrated circuit design, create a comprehensive outline addressing:
    Question: {question}
    Context: {context}

    Structure your outline with:
    1. Key concept definitions
    2. Technical implementation approaches
    3. Performance trade-offs
    4. Real-world application examples
    Output only the outline structure."""

    draft_template = """Develop a technical response based on:
    Outline: {outline}
    Context: {context}

    Include:
    - Mathematical equations where applicable
    - Circuit diagrams described in text
    - Performance metrics (speed, power, area)
    - Citations to Razavi's design principles"""

    revise_template = """Refine this draft into publication-quality content:
    Draft: {draft}
    Context: {context}

    Improvements needed:
    1. Ensure technical accuracy against context
    2. Add transitional phrases between sections
    3. Highlight design trade-offs
    4. Use professional engineering terminology
    5. Format equations clearly: V_out = f(V_in)"""

    # Create prompt templates
    outline_prompt = PromptTemplate(input_variables=["question", "context"], template=outline_template)
    draft_prompt = PromptTemplate(input_variables=["outline", "context"], template=draft_template)
    revise_prompt = PromptTemplate(input_variables=["draft", "context"], template=revise_template)

    # Step 7: Chain Construction with Memory Optimization
    outline_chain = outline_prompt | llm | StrOutputParser()
    draft_chain = draft_prompt | llm | StrOutputParser()
    revise_chain = revise_prompt | llm | StrOutputParser()

    full_chain = (
        RunnablePassthrough.assign(outline=outline_chain)
        | RunnablePassthrough.assign(draft=draft_chain)
        | revise_chain
    )

    # Step 8: Enhanced Retrieval-Generation with Context Filtering
    def generate_answer(question):
        print(f"\nProcessing question: {question}")
        # Retrieve relevant context
        docs = retriever.get_relevant_documents(question)

        # Filter context by relevance score (if available)
        filtered_docs = [doc for doc in docs if doc.metadata.get('score', 1) > 0.7][:1]

        context = "\n\n---REFERENCE---\n".join([d.page_content for d in filtered_docs])
        print(f"Retrieved {len(filtered_docs)} context chunks")

        # Execute multi-step chain
        try:
            result = full_chain.invoke({"question": question, "context": context})
            return result
        except Exception as e:
            print(f"An error occurred during chain execution: {e}")
            traceback.print_exc()
            return "Error: Could not generate an answer."

    # Step 9: Example Queries
    queries = [
        "Explain the differences of FFT vs DFFT"
    ]

    for i, query in enumerate(queries, 1):
        print(f"\n{'='*50}\nRESPONSE TO QUERY #{i}: {query}\n{'='*50}")
        answer = generate_answer(query)
        print(f"\nFINAL ANSWER:\n{answer}")
        print(f"\n{'='*50}\nEND OF RESPONSE #{i}\n{'='*50}")

except Exception as e:
    print(f"\nERROR: {str(e)}")
    traceback.print_exc()
    print("Troubleshooting Tips:")
    print("- Check PDF file exists and is readable")
    print("- Verify Hugging Face API token is valid")
    print("- Ensure sentence-transformers model is available")
    print("- Reduce chunk_size if memory errors occur")
# Out:
# Extracting and cleaning PDF text...
# Splitting documents into chunks...
# Creating vector database...
# Initializing language model...
#
# ==================================================
# RESPONSE TO QUERY #1: Explain the differences of FFT vs DFFT
# ==================================================
#
# Processing question: Explain the differences of FFT vs DFFT
# /tmp/ipython-input-14-1718573306.py:141: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = retriever.get_relevant_documents(question)
# Retrieved 1 context chunks
#
# FINAL ANSWER:
# ## Fast Fourier Transform (FFT) Algorithms: A Technical Deep Dive
#
# This document provides a comprehensive technical overview of the Discrete Fourier Transform (DFT), its efficient computation via Fast Fourier Transform (FFT) algorithms (specifically Decimation-in-Time (DIT-FFT) and Decimation-in-Frequency (DIF-FFT)), and their widespread applications.  We will analyze their implementation details, performance trade-offs, and suitability for various hardware architectures, emphasizing the crucial role of exploiting the inherent periodicity and symmetry of the DFT to achieve significant computational speedups.
#
# **I. Fundamental Concepts**
#
# **A. Discrete Fourier Transform (DFT)**
#
# The Discrete Fourier Transform (DFT) converts a sequence of *N* complex numbers, *x[n]* (n = 0, 1, ..., N-1), representing a discrete-time signal, into another sequence of *N* complex numbers, *X[k]* (k = 0, 1, ..., N-1), representing its frequency-domain components.  Mathematically, this transformation is defined as:
#
# <div align="center">
#   X[k] = Σ<sup>N-1</sup><sub>n=0</sub> x[n] * e<sup>-j2πnk/N</sup>
# </div>
#
# where *j* is the imaginary unit.  Direct computation of the DFT using this formula exhibits a time complexity of O(N²), rendering it computationally expensive for large *N*, a significant limitation in many signal processing applications. This quadratic complexity necessitates the development of more efficient algorithms.
#
#
# **B. Fast Fourier Transform (FFT)**
#
# The Fast Fourier Transform (FFT) is a family of algorithms that compute the DFT with significantly reduced computational complexity, achieving O(N log₂N) time. This dramatic improvement stems from exploiting the inherent periodicity and symmetry properties within the DFT computation.  The core principle involves recursively decomposing the DFT of size *N* into smaller DFTs of size *N/2*, *N/4*, and so on, until the problem becomes trivially solvable.  This recursive decomposition is the foundation of the two primary FFT algorithms: Decimation-in-Time (DIT-FFT) and Decimation-in-Frequency (DIF-FFT).  Common FFT implementations utilize radices such as Radix-2, Radix-4, or mixed-radix approaches, optimizing performance based on the specific value of *N* and target hardware architecture.
#
#
# **II. Decimation-in-Time and Decimation-in-Frequency FFTs**
#
# The DIT-FFT and DIF-FFT algorithms achieve the O(N log₂N) complexity through different recursive decomposition strategies.
#
# **A. Decimation-in-Frequency FFT (DIF-FFT)**
#
# The DIF-FFT recursively divides the input sequence into even- and odd-indexed subsequences.  It then recursively computes the DFTs of these subsequences and combines the results using a fundamental operation called the *butterfly operation*.  This operation, the core computational element of the FFT, involves two complex multiplications and two complex additions:
#
# <div align="center">
#   X[k] = X<sub>even</sub>[k] + W<sup>k</sup> * X<sub>odd</sub>[k]
# </div>
# <div align="center">
#   X[k + N/2] = X<sub>even</sub>[k] - W<sup>k</sup> * X<sub>odd</sub>[k]
# </div>
#
# where <div align="center">W = e<sup>-j2π/N</sup></div> is the *twiddle factor*.  The output of the DIF-FFT requires a *bit-reversal permutation* to obtain the correct frequency ordering.
#
#
# **B. Decimation-in-Time FFT (DIT-FFT)**
#
# In contrast to DIF-FFT, the DIT-FFT recursively divides the frequency spectrum into even- and odd-indexed frequency components.  Similar butterfly operations are employed, though the order of operations and twiddle factor application differ.  The key distinction lies in the application of the bit-reversal permutation:  the input sequence for DIT-FFT requires pre-processing with bit-reversal, resulting in a naturally ordered output.
#
#
# **III. Implementation Considerations and Trade-offs**
#
# The choice between DIT-FFT and DIF-FFT, and the selection of optimal parameters within each algorithm, hinges on several critical factors influencing implementation efficiency and performance.
#
# **A. Hardware and Software Implementations**
#
# Both DIT-FFT and DIF-FFT can be implemented efficiently in hardware and software.  Hardware implementations benefit from pipelining the butterfly operations and utilizing specialized hardware units for complex multiplication to minimize latency.  Efficient memory management is crucial in both hardware and software to reduce data transfer overhead.  Software implementations often leverage optimized libraries such as FFTW (Fastest Fourier Transform in the West), which provide highly optimized implementations tailored to various architectures.  Careful consideration of data structures and memory allocation strategies are essential for optimal performance.
#
#
# **B. Performance Trade-offs: A Comparative Analysis**
#
# While both algorithms achieve O(N log₂N) complexity, subtle differences impact performance.
#
# * **Computational Complexity:** Although both have the same asymptotic complexity, the constant factors and the number of operations per stage can vary, impacting actual runtime.  Higher radices (e.g., Radix-4) can reduce the number of stages but may increase the complexity of the butterfly operation.
#
# * **Memory Access:** Both algorithms can be implemented *in-place*, minimizing memory requirements to O(N).  However, the memory access patterns differ, potentially impacting performance, particularly on architectures with complex cache hierarchies.  Out-of-place implementations require O(2N) memory but may offer simpler control logic.
#
# * **Hardware Resource Utilization:** The number of logic gates, multipliers, and adders scales approximately with N log₂N.  The choice of radix influences the hardware complexity of the butterfly unit and the overall power consumption.  FPGAs and ASICs are well-suited for implementing both algorithms, but the optimal choice depends on the specific architecture and design constraints.
#
#
# **IV. Applications**
#
# FFT algorithms are ubiquitous across numerous fields.  Their efficiency in processing large datasets has revolutionized many areas of signal and data processing.
#
# * **Digital Signal Processing (DSP):**  Audio/speech processing (spectral analysis, filtering), image/video processing (compression, filtering), telecommunications (OFDM modulation/demodulation).
#
# * **Wireless Communications:** Channel equalization, multi-carrier modulation, signal detection and estimation.
#
# * **Scientific Computing:** Spectral analysis, solving partial differential equations (PDEs), image reconstruction.
#
#
# **V. Conclusion**
#
# The choice between DIT-FFT and DIF-FFT is often application-specific.  While both algorithms offer significant computational advantages over direct DFT computation, careful consideration of memory access patterns, hardware architecture, and specific application requirements is crucial for optimal performance.  Further research into specific FFT libraries and hardware architectures is recommended for detailed design and implementation in real-world applications.
#
# ==================================================
# END OF RESPONSE #1
# ==================================================
